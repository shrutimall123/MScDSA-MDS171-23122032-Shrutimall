# %%
class example:
    def __init__(self):
        self.name
        self.rengo
        self.age
myex=example()
print(self.student.index())

# %%
class students:
    def __init__(self):
        self.student=[]

    def addStudent(self, name,regno):
        self.student.append({
            "Name":name,
            "RegNo":regno
        })

    def ListAllStudents(self):
        print(self.student)
    
    def searchStudent(self,name):
        found = False
        for student in self.students:
            if student["Name"] == name:
                print("Name:", student["Name"])
                print("RegNo:", student["RegNo"])
                found = True
        
    
    def removeStudent(self,name):
        pass

    def __str__(Self):
        pass

    

mscdsa=students()

mscdsa.addStudent("Shrutii","23122022")
mscdsa.addStudent("Shruthi","23122023")
mscdsa.addStudent("Abitg","23122033")
mscdsa.ListAllStudents()

# %%
temp=[{'Name': 'Shrutii', 'RegNo': '23122022'}, {'Name': 'Shruthi', 'RegNo': '23122023'}, {'Name': 'Abitg', 'RegNo': '23122033'}]
temp

# %%
for item in temp:
    print(item['Name'])

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

students={
    'Name':['Abhi','shruti','nikki','hiran','Anand'],
    'Age':[23,22,22,21,24]
}

print(students)


print("")
print("")


df=pd.DataFrame(students)
print(df.head())
print("")
print("")
print(df.tail())
df.head()
df.tail()
# Out:
# {'Name': ['Abhi', 'shruti', 'nikki', 'hiran', 'Anand'], 'Age': [23, 22, 22, 21, 24]}
#
#
#      Name  Age
# 0    Abhi   23
# 1  shruti   22
# 2   nikki   22
# 3   hiran   21
# 4   Anand   24
#
#
#      Name  Age
# 0    Abhi   23
# 1  shruti   22
# 2   nikki   22
# 3   hiran   21
# 4   Anand   24
#      Name  Age
# 0    Abhi   23
# 1  shruti   22
# 2   nikki   22
# 3   hiran   21
# 4   Anand   24

# %%
pd.read_csv("Expense.csv")
# Out:
#        Type       Category    Cost                              Description  \
# 0    Income         Salary  200000                           Monthly Salary
# 1    Income          Bonus   10000                    I got my Diwali Bonus
# 2   Expense           Food     200            I orderd food from the market
# 3   Expense         Travel   12000                  I went to Mahabaleshwar
# 4   Expense         Health    1500  I went to doctor for my routine checkup
# 5   Expense           Bill     500                       Paid internet Bill
# 6   Expense     Dining Out     500                Had dinner with my family
# 7   Expense      Groceries    2500            Bought some necessary grocery
# 8    Income   Extra Income   50000               I have rented my apartment
# 9    Income       Dividend    3000                  I got mt first dividend
# 10  Expense           Bill    2400                       Paid internet Bill
# ...

# %%
sf= pd.read_csv("Expense.csv")
sf.head(20)
# Out:
#        Type       Category    Cost                              Description  \
# 0    Income         Salary  200000                           Monthly Salary
# 1    Income          Bonus   10000                    I got my Diwali Bonus
# 2   Expense           Food     200            I orderd food from the market
# 3   Expense         Travel   12000                  I went to Mahabaleshwar
# 4   Expense         Health    1500  I went to doctor for my routine checkup
# 5   Expense           Bill     500                       Paid internet Bill
# 6   Expense     Dining Out     500                Had dinner with my family
# 7   Expense      Groceries    2500            Bought some necessary grocery
# 8    Income   Extra Income   50000               I have rented my apartment
# 9    Income       Dividend    3000                  I got mt first dividend
# 10  Expense           Bill    2400                       Paid internet Bill
# ...

# %%
sf.tail(10)
# Out:
#        Type       Category   Cost                         Description  \
# 10  Expense           Bill   2400                  Paid internet Bill
# 11  Expense           Bill   1200                     Paid water Bill
# 12  Expense           Bill   1000                           Paid Bill
# 13  Expense     Dining Out    500                 Went to eat outside
# 14  Expense         Travel  15000             Visited Jammu & Kashmir
# 15  Expense  Miscellaneous    130          Gave money to my housemaid
# 16  Expense         Travel  20000                      Visited Manali
# 17  Expense          Movie    500                         Jawan movie
# 18  Expesse           Food    400                        Ordered food
# 19  Expense         Health   2000  Went to doctor for monthly checkup
#
#           Date
# 10  22-08-2023
# 11  23-08-2023
# 12  24-08-2023
# 13  25-08-2023
# 14  26-08-2023
# 15  27-08-2023
# 16  28-08-2023
# 17  29-08-2023
# 18  30-08-2023
# 19  31-08-2023

# %%
sf.columns
# Out:
# Index(['Type', 'Category', 'Cost', 'Description', 'Date'], dtype='object')

# %%
df.describe()
# Out:
#                 Cost
# count      20.000000
# mean    16166.500000
# std     44822.927906
# min       130.000000
# 25%       500.000000
# 50%      1750.000000
# 75%     10500.000000
# max    200000.000000

# %%
df.columns
# Out:
# Index(['Type', 'Category', 'Cost', 'Description', 'Date'], dtype='object')

# %%
df['Cost']
# Out:
# 0     200000
# 1      10000
# 2        200
# 3      12000
# 4       1500
# 5        500
# 6        500
# 7       2500
# 8      50000
# 9       3000
# 10      2400
# 11      1200
# 12      1000
# 13       500
# 14     15000
# 15       130
# 16     20000
# 17       500
# 18       400
# 19      2000
# Name: Cost, dtype: int64

# %%
sf['Cost'].hist()
sf['Date'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Create a class pandas_name that will help you to read a csv file and print the top/bottom n rows in the file.

# %%
class pandas_name:
    def __init__(self,data):
        self.filecontent=[]
        
    def read_csv(self,filename):
        with open(filename,"r+") as file:
            self.filecontent=file.readlines()

    def head(self,num):
        print(self.filecontent[:num])
        
    def tail(slf,num=5):
        tmp = print(self.filecontent[len(self.filecontent)-num])
        for item in tmp:
            print(item.strip())

# %%
class pandas_Shruti:
    def __init__(self):
        self.filename=""
        self.filecontent=""
    
    def read_csv(self,filename):
        self.filename = filename
        try:
            with open(filename,"r") as file:
                self.filecontent=file.readlines()
        
        except:
            print("file not found")

    def head(self, num_of_rows):
        for i in range(0,num_of_rows):
            print(self.filecontent[i])

    def tail(self, num_of_rows):
        start=len(self.filecontent)-(num_of_rows-1)
        end= len(self.filecontent)-1       
        for i in range(len(self.filecontent)-(num_of_rows),len(self.filecontent)):
            print(self.filecontent[i].strip())

# %%
pd=pandas_Shruti()
pd.read_csv("Expense.csv")
pd.head(2)
pd.tail(2)
# Out:
# Type,Category,Cost,Description,Date
#
# Income,Salary,200000,Monthly Salary,12-08-2023
#
# Expesse,Food,400,Ordered food,30-08-2023
# Expense,Health,2000,Went to doctor for monthly checkup,31-08-2023

# %%
import pandas as pd
df=pd.read_csv("Expense.csv")
print(df.head(2))
print(df.tail(2))
print(df.columns)
# Out:
#      Type Category    Cost            Description        Date
# 0  Income   Salary  200000         Monthly Salary  12-08-2023
# 1  Income    Bonus   10000  I got my Diwali Bonus  13-08-2023
#        Type Category  Cost                         Description        Date
# 18  Expesse     Food   400                        Ordered food  30-08-2023
# 19  Expense   Health  2000  Went to doctor for monthly checkup  31-08-2023
# Index(['Type', 'Category', 'Cost', 'Description', 'Date'], dtype='object')

# %%
df[['Type','Description','Date','Cost']]
# Out:
#        Type                              Description        Date    Cost
# 0    Income                           Monthly Salary  12-08-2023  200000
# 1    Income                    I got my Diwali Bonus  13-08-2023   10000
# 2   Expense            I orderd food from the market  14-08-2023     200
# 3   Expense                  I went to Mahabaleshwar  15-08-2023   12000
# 4   Expense  I went to doctor for my routine checkup  16-08-2023    1500
# 5   Expense                       Paid internet Bill  17-08-2023     500
# 6   Expense                Had dinner with my family  18-08-2023     500
# 7   Expense            Bought some necessary grocery  19-08-2023    2500
# 8    Income               I have rented my apartment  20-08-2023   50000
# 9    Income                  I got mt first dividend  21-08-2023    3000
# 10  Expense                       Paid internet Bill  22-08-2023    2400
# 11  Expense                          Paid water Bill  23-08-2023    1200
# ...

# %%
df['Cost'].hist()
# Out:
# <Axes: >

# %%
df[['Cost']]
# Out:
#       Cost
# 0   200000
# 1    10000
# 2      200
# 3    12000
# 4     1500
# 5      500
# 6      500
# 7     2500
# 8    50000
# 9     3000
# 10    2400
# 11    1200
# 12    1000
# 13     500
# 14   15000
# 15     130
# 16   20000
# 17     500
# 18     400
# 19    2000

# %% [markdown]
# Write a python Program that will read a csv file and print the mean median mode for a column of usrer choice

# %%
def read_csv():
    file1=open("Expenses.csv", 'r') 
    for 
    print(file1)

# %%
filename="Expenses.csv"

# %%
print(filename)
# Out:
# Expenses.csv

# %%
from csv import reader
def load_csv(filename):
    file = open(filename,"r")
    lines = reader(file) 
    data = list(lines)
    return data

if __name__ == "__main__":
    # Path of the dataset
    file_path = "Expense.csv"
    data = load_csv(file_path)
    
    # Let's print the first 5 datapoints
    for row in data[:21]:
        print(row, end = "\n")

    for row in rows[2:21]:
        for col in row[]
# Out:
#   Cell In[65], line 18
#     for col in row[]
#                    ^
# SyntaxError: invalid syntax

# %%
def read_csv():
    with open("Expense5.csv","r+")as file:
        content=file.readlines()
    for item in content:
        item=item.split(",")
        print(item)
        for i in item:
            store=i.split(",")
        print(store)
read_csv()
# Out:
# ['\ufeffType', 'Category', 'Cost', 'Description', 'Date\n']
# ['Date\n']
# ['Income', 'Salary', '200000', 'Monthly Salary', '12-08-2023\n']
# ['12-08-2023\n']
# ['Income', 'Bonus', '10000', 'I got my Diwali Bonus', '13-08-2023\n']
# ['13-08-2023\n']
# ['Expense', 'Food', '200', 'I orderd food from the market', '14-08-2023\n']
# ['14-08-2023\n']
# ['Expense', 'Travel', '12000', 'I went to Mahabaleshwar', '15-08-2023\n']
# ['15-08-2023\n']
# ['Expense', 'Health', '1500', 'I went to doctor for my routine checkup', '16-08-2023\n']
# ['16-08-2023\n']
# ['Expense', 'Bill', '500', 'Paid internet Bill', '17-08-2023\n']
# ['17-08-2023\n']
# ['Expense', 'Dining Out', '500', 'Had dinner with my family', '18-08-2023\n']
# ['18-08-2023\n']
# ['Expense', 'Groceries', '2500', 'Bought some necessary grocery', '19-08-2023\n']
# ['19-08-2023\n']
# ['Income', 'Extra Income', '50000', 'I have rented my apartment', '20-08-2023\n']
# ['20-08-2023\n']
# ...
